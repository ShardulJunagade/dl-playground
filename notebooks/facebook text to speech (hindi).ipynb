# %%
# !pip install -U transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 76.8 MB/s eta 0:00:00:00:01:01
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.51.3
#     Uninstalling transformers-4.51.3:
#       Successfully uninstalled transformers-4.51.3
# ...

# %% [markdown]
# Model page: https://huggingface.co/facebook/mms-tts-hin
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/facebook/mms-tts-hin)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-to-speech", model="facebook/mms-tts-hin")
# text = "यह एक उदाहरण वाक्य है।"
text = """
बिलकुल! यहाँ कुछ यादृच्छिक (random) हिंदी पाठ है:

आज की सुबह बहुत सुहानी थी। हल्की ठंडी हवा चल रही थी और आसमान में सूरज बादलों की ओट से झांक रहा था। चाय की प्याली हाथ में लेकर बालकनी में खड़े होना एक अलग ही सुकून देता है। पास के पेड़ पर एक तोता बैठा अपनी ही धुन में कुछ बोल रहा था। ज़िंदगी की भागदौड़ में ऐसे छोटे-छोटे लम्हे बहुत खास होते हैं।

अगर आप किसी विशेष शैली, विषय, या मूड में हिंदी पाठ चाहते हैं (जैसे रोमांटिक, हास्य, गद्य, कविता आदि), तो मुझे बताएं!
"""
output = pipe(text)
# Out:
# Device set to use cuda:0

# %%
print(output)
# Out:
# {'audio': array([[ 9.4083225e-06,  5.7003544e-06,  1.7163284e-05, ...,
#          2.2115297e-05,  2.7776221e-06, -1.9714882e-05]], dtype=float32), 'sampling_rate': 16000}

# %%
import IPython.display as ipd

ipd.Audio(output["audio"], rate=output["sampling_rate"])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
